# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd='C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
img=cv2.imread('6.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
text=pytesseract.image_to_string(img)
print(text)
# Out:
# All About the Importance of Document Destruction and
# Commercial Paper Shredders
#
# Documents are an essential part of every govemment and corporate office. You can find them in
# ‘alnost every office and a special room i alloted to keep them for security purpose. ‘The reason
# behind so mich secwity is that sometimes these documents contain infomation which is
# confidential This information should not be disclosed at any point, as thi can be a threat for the
# inmge of the organization Conflental information in documents may also inchde detail about
# its working and manufacturing process. ‘This information is crucialy important for the working
# of organization and rival can wse it to launch @ counterpart in market, which can be catastrophic.
#
# ‘The company may soon bse is positon in market and business earned by it
#
# ‘The above paragraph clearly descrbes the importance of documents for any organization,
# However the security of every document paper in the organization is not possible, especialy the
# uses ones are at high risk. There have been many instants when empbyees and strangers have
# picked up papers fom dustbins and extracted confidential information. In case you own a
# ‘business organization then I woukl advise you to be very carefil while towing away those
# papers which have the possiiity to comin priate information about the working processes
# These papers should be shredded down into small pieces that can never be put together before
#
# discarding.
#
# Document destruction & an important task that needs to be accomplshed with great care in any
# corporate or govemment organization ‘he ordinary paper slvedder that you have at homes and
# schools camot be wed in corporate or govemment offices. These paper shredders convert paper
# ino swps that one can easly put together. Therefore the infomation that the sinedded papers
# hhave i sill at high sk of being extracted discreet. To find an effective solaion to this
# problem commercial paper shredder was imemted. ‘Ths shredder designed to convest paper
#
# imo tiniest pizces, which is essential to secure the information in document papers.
#
# Paper shredders that you see in office are technologically advanced and they are specially
# designed for commercial we. These shredders make document destruction work easy and
# effective thereby secung ll the important information fiom intmuders, If you have yet not
#
# purchased them for your office then consider investing on few of them You can buy them online
